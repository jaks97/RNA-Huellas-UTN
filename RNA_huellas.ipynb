# %% [markdown]
# <a href="https://colab.research.google.com/github/jaks97/RNA-Huellas-UTN/blob/main/RNA_huellas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho = 64 #@param {type:"integer"}
imagen_color = False #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True # param {type:"boolean"}

#@markdown ### Parámetros de la red:
rna_cant_neuronas_capas_ocultas = '3200, 1000, 720, 120, 10' #@param {type:"string"}
rna_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento = 500 #@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# cantidad de neuronas ocultas 
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )  
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )  
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print ("Tamaño Imagen: ", IMAGE_SHAPE)
print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Tamaño Imagen:  (64, 64, 1)
# Configuración de RNA MLP Backpropagation definida:
# [ 4096 ['3200', '1000', '720', '120', '10'] Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  20
# - Imágenes cargadas:  20
# - Ejemplo  3 dedos   (64, 64) :
# <PIL.Image.Image image mode=L size=64x64 at 0x7FC865001910>
# > Para Prueba:
# - Clases cargadas:  47
# - Imágenes cargadas:  47
# - Ejemplo  3 dedos   (64, 64) :
# <PIL.Image.Image image mode=L size=64x64 at 0x7FC8650013D0>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (20, 4096)
#  - y_trainEnc (cant):  20
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (47, 4096)
#  - y_testEnc (cant):  47
#
#
# > Para Ambos:
#  - dictMapeo:  {'3 dedos': 0, '5 dedos': 1, '4 dedos': 2, '2 dedos': 3}
#  - clases_map:  ['3 dedos', '5 dedos', '4 dedos', '2 dedos']
#
#  - Imagen reconstruida de  3 dedos ( 0  /  [1. 0. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
#@title Establecer modelo

opt_tipo = "Gradiente Decreciente" #@param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.001 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for val_hid in hidden_layers:  

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  7  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 4096)]            0
#
#  hidd_1 (Dense)              (None, 3200)              13110400
#
#  hidd_2 (Dense)              (None, 1000)              3201000
#
#  hidd_3 (Dense)              (None, 720)               720720
#
#  hidd_4 (Dense)              (None, 120)               86520
#
#  hidd_5 (Dense)              (None, 10)                1210
#
#  output (Dense)              (None, 4)                 44
#
# =================================================================
# Total params: 17,119,894
# Trainable params: 17,119,894
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False 

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  20 ejemplos de entrenamiento:
#             se usan  18 ejemplos para entrenar
#             y  2 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/500
# 1/1 [==============================] - 0s 492ms/step - loss: 2.1388 - accuracy: 0.3333 - val_loss: 14.6051 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 1/1 [==============================] - 0s 27ms/step - loss: 8.5665 - accuracy: 0.2778 - val_loss: 1.4356 - val_accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 26ms/step - loss: 7.1579 - accuracy: 0.6111 - val_loss: 13.4013 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 1/1 [==============================] - 0s 28ms/step - loss: 9.7084 - accuracy: 0.2778 - val_loss: 0.2661 - val_accuracy: 1.0000
# Epoch 5/500
# 1/1 [==============================] - 0s 27ms/step - loss: 17.4553 - accuracy: 0.4444 - val_loss: 9.0463 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 1/1 [==============================] - 0s 27ms/step - loss: 8.0309 - accuracy: 0.2778 - val_loss: 0.8198 - val_accuracy: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 40ms/step - loss: 10.4773 - accuracy: 0.2222 - val_loss: 21.4756 - val_accuracy: 0.0000e+00
# Epoch 8/500
# 1/1 [==============================] - 0s 27ms/step - loss: 11.8239 - accuracy: 0.2778 - val_loss: 4.2654 - val_accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 26ms/step - loss: 11.3030 - accuracy: 0.2222 - val_loss: 13.5451 - val_accuracy: 0.0000e+00
# Epoch 10/500
# 1/1 [==============================] - 0s 28ms/step - loss: 8.5948 - accuracy: 0.2778 - val_loss: 1.6961 - val_accuracy: 0.5000
# Epoch 11/500
# 1/1 [==============================] - 0s 27ms/step - loss: 5.4944 - accuracy: 0.2778 - val_loss: 19.3669 - val_accuracy: 0.0000e+00
# Epoch 12/500
# 1/1 [==============================] - 0s 27ms/step - loss: 8.7886 - accuracy: 0.2778 - val_loss: 1.9314 - val_accuracy: 0.5000
# Epoch 13/500
# 1/1 [==============================] - 0s 27ms/step - loss: 5.6553 - accuracy: 0.5000 - val_loss: 3.5058 - val_accuracy: 0.0000e+00
# Epoch 14/500
# 1/1 [==============================] - 0s 26ms/step - loss: 2.4308 - accuracy: 0.5000 - val_loss: 0.5360 - val_accuracy: 0.5000
# Epoch 15/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.8088 - accuracy: 0.6111 - val_loss: 6.4477 - val_accuracy: 0.0000e+00
# Epoch 16/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2971 - accuracy: 0.6667 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 17/500
# 1/1 [==============================] - 0s 30ms/step - loss: 2.1061 - accuracy: 0.5556 - val_loss: 10.3719 - val_accuracy: 0.0000e+00
# Epoch 18/500
# 1/1 [==============================] - 0s 27ms/step - loss: 2.4424 - accuracy: 0.6111 - val_loss: 0.0935 - val_accuracy: 1.0000
# Epoch 19/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6078 - accuracy: 0.5556 - val_loss: 10.1480 - val_accuracy: 0.0000e+00
# Epoch 20/500
# 1/1 [==============================] - 0s 28ms/step - loss: 2.7365 - accuracy: 0.6111 - val_loss: 0.1845 - val_accuracy: 1.0000
# Epoch 21/500
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0515 - accuracy: 0.7222 - val_loss: 4.5957 - val_accuracy: 0.0000e+00
# Epoch 22/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4782 - accuracy: 0.7778 - val_loss: 0.2501 - val_accuracy: 1.0000
# Epoch 23/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2615 - accuracy: 0.8889 - val_loss: 2.5418 - val_accuracy: 0.0000e+00
# Epoch 24/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1630 - accuracy: 0.9444 - val_loss: 1.0225 - val_accuracy: 0.5000
# Epoch 25/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.9938 - val_accuracy: 0.5000
# Epoch 26/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.9946 - val_accuracy: 0.5000
# Epoch 27/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.5000
# Epoch 28/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.9915 - val_accuracy: 0.5000
# Epoch 29/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.5000
# Epoch 30/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.9931 - val_accuracy: 0.5000
# Epoch 31/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.9946 - val_accuracy: 0.5000
# Epoch 32/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.9963 - val_accuracy: 0.5000
# Epoch 33/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.9982 - val_accuracy: 0.5000
# Epoch 34/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 1.0002 - val_accuracy: 0.5000
# Epoch 35/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 1.0021 - val_accuracy: 0.5000
# Epoch 36/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 1.0040 - val_accuracy: 0.5000
# Epoch 37/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 1.0059 - val_accuracy: 0.5000
# Epoch 38/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 1.0078 - val_accuracy: 0.5000
# Epoch 39/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 1.0096 - val_accuracy: 0.5000
# Epoch 40/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 1.0113 - val_accuracy: 0.5000
# Epoch 41/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.5000
# Epoch 42/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 1.0146 - val_accuracy: 0.5000
# Epoch 43/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 1.0161 - val_accuracy: 0.5000
# Epoch 44/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 1.0176 - val_accuracy: 0.5000
# Epoch 45/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.0190 - val_accuracy: 0.5000
# Epoch 46/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.0204 - val_accuracy: 0.5000
# Epoch 47/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.0217 - val_accuracy: 0.5000
# Epoch 48/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.0229 - val_accuracy: 0.5000
# Epoch 49/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 1.0240 - val_accuracy: 0.5000
# Epoch 50/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.0251 - val_accuracy: 0.5000
# Epoch 51/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.5000
# Epoch 52/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 1.0272 - val_accuracy: 0.5000
# Epoch 53/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.0281 - val_accuracy: 0.5000
# Epoch 54/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 1.0290 - val_accuracy: 0.5000
# Epoch 55/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.5000
# Epoch 56/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 1.0306 - val_accuracy: 0.5000
# Epoch 57/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 1.0313 - val_accuracy: 0.5000
# Epoch 58/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 1.0320 - val_accuracy: 0.5000
# Epoch 59/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 1.0327 - val_accuracy: 0.5000
# Epoch 60/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 1.0333 - val_accuracy: 0.5000
# Epoch 61/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 1.0338 - val_accuracy: 0.5000
# Epoch 62/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.0344 - val_accuracy: 0.5000
# Epoch 63/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 64/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 1.0353 - val_accuracy: 0.5000
# Epoch 65/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 1.0357 - val_accuracy: 0.5000
# Epoch 66/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 1.0361 - val_accuracy: 0.5000
# Epoch 67/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 1.0364 - val_accuracy: 0.5000
# Epoch 68/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 1.0368 - val_accuracy: 0.5000
# Epoch 69/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.0370 - val_accuracy: 0.5000
# Epoch 70/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 1.0373 - val_accuracy: 0.5000
# Epoch 71/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 1.0375 - val_accuracy: 0.5000
# Epoch 72/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 1.0377 - val_accuracy: 0.5000
# Epoch 73/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 1.0379 - val_accuracy: 0.5000
# Epoch 74/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 1.0381 - val_accuracy: 0.5000
# Epoch 75/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.0382 - val_accuracy: 0.5000
# Epoch 76/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 1.0383 - val_accuracy: 0.5000
# Epoch 77/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 1.0384 - val_accuracy: 0.5000
# Epoch 78/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 79/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 80/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 81/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 82/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 83/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 84/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.5000
# Epoch 85/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 1.0384 - val_accuracy: 0.5000
# Epoch 86/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 1.0384 - val_accuracy: 0.5000
# Epoch 87/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 1.0383 - val_accuracy: 0.5000
# Epoch 88/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.0382 - val_accuracy: 0.5000
# Epoch 89/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.0381 - val_accuracy: 0.5000
# Epoch 90/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.0380 - val_accuracy: 0.5000
# Epoch 91/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 1.0378 - val_accuracy: 0.5000
# Epoch 92/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 1.0377 - val_accuracy: 0.5000
# Epoch 93/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.0375 - val_accuracy: 0.5000
# Epoch 94/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 1.0374 - val_accuracy: 0.5000
# Epoch 95/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.0372 - val_accuracy: 0.5000
# Epoch 96/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 1.0370 - val_accuracy: 0.5000
# Epoch 97/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 1.0369 - val_accuracy: 0.5000
# Epoch 98/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 1.0367 - val_accuracy: 0.5000
# Epoch 99/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 1.0365 - val_accuracy: 0.5000
# Epoch 100/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 1.0363 - val_accuracy: 0.5000
# Epoch 101/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.0360 - val_accuracy: 0.5000
# Epoch 102/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 1.0358 - val_accuracy: 0.5000
# Epoch 103/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 1.0356 - val_accuracy: 0.5000
# Epoch 104/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.0354 - val_accuracy: 0.5000
# Epoch 105/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.5000
# Epoch 106/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 107/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.5000
# Epoch 108/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 1.0344 - val_accuracy: 0.5000
# Epoch 109/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 1.0341 - val_accuracy: 0.5000
# Epoch 110/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 1.0339 - val_accuracy: 0.5000
# Epoch 111/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.5000
# Epoch 112/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.0334 - val_accuracy: 0.5000
# Epoch 113/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 1.0331 - val_accuracy: 0.5000
# Epoch 114/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 1.0328 - val_accuracy: 0.5000
# Epoch 115/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.0325 - val_accuracy: 0.5000
# Epoch 116/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 1.0323 - val_accuracy: 0.5000
# Epoch 117/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.0320 - val_accuracy: 0.5000
# Epoch 118/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.0317 - val_accuracy: 0.5000
# Epoch 119/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 1.0314 - val_accuracy: 0.5000
# Epoch 120/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 1.0311 - val_accuracy: 0.5000
# Epoch 121/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 1.0309 - val_accuracy: 0.5000
# Epoch 122/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.0306 - val_accuracy: 0.5000
# Epoch 123/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 1.0303 - val_accuracy: 0.5000
# Epoch 124/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 1.0300 - val_accuracy: 0.5000
# Epoch 125/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.0297 - val_accuracy: 0.5000
# Epoch 126/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 1.0294 - val_accuracy: 0.5000
# Epoch 127/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 1.0291 - val_accuracy: 0.5000
# Epoch 128/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 1.0288 - val_accuracy: 0.5000
# Epoch 129/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.0285 - val_accuracy: 0.5000
# Epoch 130/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.0282 - val_accuracy: 0.5000
# Epoch 131/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.0279 - val_accuracy: 0.5000
# Epoch 132/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.0276 - val_accuracy: 0.5000
# Epoch 133/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 1.0273 - val_accuracy: 0.5000
# Epoch 134/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 1.0271 - val_accuracy: 0.5000
# Epoch 135/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.0268 - val_accuracy: 0.5000
# Epoch 136/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.0265 - val_accuracy: 0.5000
# Epoch 137/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.5000
# Epoch 138/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.0259 - val_accuracy: 0.5000
# Epoch 139/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 1.0256 - val_accuracy: 0.5000
# Epoch 140/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.0253 - val_accuracy: 0.5000
# Epoch 141/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.0250 - val_accuracy: 0.5000
# Epoch 142/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.0247 - val_accuracy: 0.5000
# Epoch 143/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.0244 - val_accuracy: 0.5000
# Epoch 144/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.5000
# Epoch 145/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.0238 - val_accuracy: 0.5000
# Epoch 146/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.0235 - val_accuracy: 0.5000
# Epoch 147/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.0232 - val_accuracy: 0.5000
# Epoch 148/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.0229 - val_accuracy: 0.5000
# Epoch 149/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 1.0226 - val_accuracy: 0.5000
# Epoch 150/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.0224 - val_accuracy: 0.5000
# Epoch 151/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.0221 - val_accuracy: 0.5000
# Epoch 152/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.0218 - val_accuracy: 0.5000
# Epoch 153/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.0215 - val_accuracy: 0.5000
# Epoch 154/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.0212 - val_accuracy: 0.5000
# Epoch 155/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.0209 - val_accuracy: 0.5000
# Epoch 156/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.0206 - val_accuracy: 0.5000
# Epoch 157/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.0204 - val_accuracy: 0.5000
# Epoch 158/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.5000
# Epoch 159/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.0198 - val_accuracy: 0.5000
# Epoch 160/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.5000
# Epoch 161/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.0192 - val_accuracy: 0.5000
# Epoch 162/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.0190 - val_accuracy: 0.5000
# Epoch 163/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.0187 - val_accuracy: 0.5000
# Epoch 164/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.0184 - val_accuracy: 0.5000
# Epoch 165/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.0182 - val_accuracy: 0.5000
# Epoch 166/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.0179 - val_accuracy: 0.5000
# Epoch 167/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.0176 - val_accuracy: 0.5000
# Epoch 168/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.0173 - val_accuracy: 0.5000
# Epoch 169/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.0171 - val_accuracy: 0.5000
# Epoch 170/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 1.0168 - val_accuracy: 0.5000
# Epoch 171/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 1.0165 - val_accuracy: 0.5000
# Epoch 172/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.0163 - val_accuracy: 0.5000
# Epoch 173/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.0160 - val_accuracy: 0.5000
# Epoch 174/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.0158 - val_accuracy: 0.5000
# Epoch 175/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.0155 - val_accuracy: 0.5000
# Epoch 176/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.0152 - val_accuracy: 0.5000
# Epoch 177/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.0150 - val_accuracy: 0.5000
# Epoch 178/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.0147 - val_accuracy: 0.5000
# Epoch 179/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 1.0145 - val_accuracy: 0.5000
# Epoch 180/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 1.0142 - val_accuracy: 0.5000
# Epoch 181/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.0140 - val_accuracy: 0.5000
# Epoch 182/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.0137 - val_accuracy: 0.5000
# Epoch 183/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.0135 - val_accuracy: 0.5000
# Epoch 184/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.0132 - val_accuracy: 0.5000
# Epoch 185/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.5000
# Epoch 186/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.0128 - val_accuracy: 0.5000
# Epoch 187/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.0125 - val_accuracy: 0.5000
# Epoch 188/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.0123 - val_accuracy: 0.5000
# Epoch 189/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.0120 - val_accuracy: 0.5000
# Epoch 190/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0118 - val_accuracy: 0.5000
# Epoch 191/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0116 - val_accuracy: 0.5000
# Epoch 192/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.0113 - val_accuracy: 0.5000
# Epoch 193/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.0111 - val_accuracy: 0.5000
# Epoch 194/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.0109 - val_accuracy: 0.5000
# Epoch 195/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.0106 - val_accuracy: 0.5000
# Epoch 196/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.0104 - val_accuracy: 0.5000
# Epoch 197/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.0102 - val_accuracy: 0.5000
# Epoch 198/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.0099 - val_accuracy: 0.5000
# Epoch 199/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.0097 - val_accuracy: 0.5000
# Epoch 200/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.0095 - val_accuracy: 0.5000
# Epoch 201/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.0093 - val_accuracy: 0.5000
# Epoch 202/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.0091 - val_accuracy: 0.5000
# Epoch 203/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.5000
# Epoch 204/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.0086 - val_accuracy: 0.5000
# Epoch 205/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.5000
# Epoch 206/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.0082 - val_accuracy: 0.5000
# Epoch 207/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.0080 - val_accuracy: 0.5000
# Epoch 208/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.0078 - val_accuracy: 0.5000
# Epoch 209/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.0076 - val_accuracy: 0.5000
# Epoch 210/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.0073 - val_accuracy: 0.5000
# Epoch 211/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.0071 - val_accuracy: 0.5000
# Epoch 212/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.0069 - val_accuracy: 0.5000
# Epoch 213/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.0067 - val_accuracy: 0.5000
# Epoch 214/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.0065 - val_accuracy: 0.5000
# Epoch 215/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.0063 - val_accuracy: 0.5000
# Epoch 216/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.0061 - val_accuracy: 0.5000
# Epoch 217/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.0059 - val_accuracy: 0.5000
# Epoch 218/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.0057 - val_accuracy: 0.5000
# Epoch 219/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.0055 - val_accuracy: 0.5000
# Epoch 220/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.0053 - val_accuracy: 0.5000
# Epoch 221/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.0051 - val_accuracy: 0.5000
# Epoch 222/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.0049 - val_accuracy: 0.5000
# Epoch 223/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.0047 - val_accuracy: 0.5000
# Epoch 224/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.0046 - val_accuracy: 0.5000
# Epoch 225/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.0044 - val_accuracy: 0.5000
# Epoch 226/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.0042 - val_accuracy: 0.5000
# Epoch 227/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.0040 - val_accuracy: 0.5000
# Epoch 228/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.5000
# Epoch 229/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.0036 - val_accuracy: 0.5000
# Epoch 230/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.0034 - val_accuracy: 0.5000
# Epoch 231/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.0033 - val_accuracy: 0.5000
# Epoch 232/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.0031 - val_accuracy: 0.5000
# Epoch 233/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.0029 - val_accuracy: 0.5000
# Epoch 234/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.0027 - val_accuracy: 0.5000
# Epoch 235/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.0025 - val_accuracy: 0.5000
# Epoch 236/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.0024 - val_accuracy: 0.5000
# Epoch 237/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.0022 - val_accuracy: 0.5000
# Epoch 238/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.0020 - val_accuracy: 0.5000
# Epoch 239/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.5000
# Epoch 240/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.0017 - val_accuracy: 0.5000
# Epoch 241/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.0015 - val_accuracy: 0.5000
# Epoch 242/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.0013 - val_accuracy: 0.5000
# Epoch 243/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.0012 - val_accuracy: 0.5000
# Epoch 244/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0010 - val_accuracy: 0.5000
# Epoch 245/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0008 - val_accuracy: 0.5000
# Epoch 246/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0007 - val_accuracy: 0.5000
# Epoch 247/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0005 - val_accuracy: 0.5000
# Epoch 248/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0003 - val_accuracy: 0.5000
# Epoch 249/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0002 - val_accuracy: 0.5000
# Epoch 250/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.0000 - val_accuracy: 0.5000
# Epoch 251/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.9999 - val_accuracy: 0.5000
# Epoch 252/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.9997 - val_accuracy: 0.5000
# Epoch 253/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.5000
# Epoch 254/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.9994 - val_accuracy: 0.5000
# Epoch 255/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.9992 - val_accuracy: 0.5000
# Epoch 256/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.9991 - val_accuracy: 0.5000
# Epoch 257/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9989 - val_accuracy: 0.5000
# Epoch 258/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9988 - val_accuracy: 0.5000
# Epoch 259/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9986 - val_accuracy: 0.5000
# Epoch 260/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9985 - val_accuracy: 0.5000
# Epoch 261/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9983 - val_accuracy: 0.5000
# Epoch 262/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9982 - val_accuracy: 0.5000
# Epoch 263/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9981 - val_accuracy: 0.5000
# Epoch 264/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9979 - val_accuracy: 0.5000
# Epoch 265/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9978 - val_accuracy: 0.5000
# Epoch 266/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9976 - val_accuracy: 0.5000
# Epoch 267/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9975 - val_accuracy: 0.5000
# Epoch 268/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9973 - val_accuracy: 0.5000
# Epoch 269/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9972 - val_accuracy: 0.5000
# Epoch 270/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9971 - val_accuracy: 0.5000
# Epoch 271/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.9969 - val_accuracy: 0.5000
# Epoch 272/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.9968 - val_accuracy: 0.5000
# Epoch 273/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.9967 - val_accuracy: 0.5000
# Epoch 274/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9965 - val_accuracy: 0.5000
# Epoch 275/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9964 - val_accuracy: 0.5000
# Epoch 276/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9963 - val_accuracy: 0.5000
# Epoch 277/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9961 - val_accuracy: 0.5000
# Epoch 278/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.5000
# Epoch 279/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9959 - val_accuracy: 0.5000
# Epoch 280/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9957 - val_accuracy: 0.5000
# Epoch 281/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9956 - val_accuracy: 0.5000
# Epoch 282/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9955 - val_accuracy: 0.5000
# Epoch 283/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9953 - val_accuracy: 0.5000
# Epoch 284/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9952 - val_accuracy: 0.5000
# Epoch 285/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9951 - val_accuracy: 0.5000
# Epoch 286/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9950 - val_accuracy: 0.5000
# Epoch 287/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9948 - val_accuracy: 0.5000
# Epoch 288/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9947 - val_accuracy: 0.5000
# Epoch 289/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9946 - val_accuracy: 0.5000
# Epoch 290/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9945 - val_accuracy: 0.5000
# Epoch 291/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9944 - val_accuracy: 0.5000
# Epoch 292/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9942 - val_accuracy: 0.5000
# Epoch 293/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9941 - val_accuracy: 0.5000
# Epoch 294/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9940 - val_accuracy: 0.5000
# Epoch 295/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9939 - val_accuracy: 0.5000
# Epoch 296/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9938 - val_accuracy: 0.5000
# Epoch 297/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9937 - val_accuracy: 0.5000
# Epoch 298/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9936 - val_accuracy: 0.5000
# Epoch 299/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9934 - val_accuracy: 0.5000
# Epoch 300/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9933 - val_accuracy: 0.5000
# Epoch 301/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9932 - val_accuracy: 0.5000
# Epoch 302/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9931 - val_accuracy: 0.5000
# Epoch 303/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9930 - val_accuracy: 0.5000
# Epoch 304/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9929 - val_accuracy: 0.5000
# Epoch 305/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9928 - val_accuracy: 0.5000
# Epoch 306/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9927 - val_accuracy: 0.5000
# Epoch 307/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9926 - val_accuracy: 0.5000
# Epoch 308/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9925 - val_accuracy: 0.5000
# Epoch 309/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9924 - val_accuracy: 0.5000
# Epoch 310/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.5000
# Epoch 311/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9921 - val_accuracy: 0.5000
# Epoch 312/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9920 - val_accuracy: 0.5000
# Epoch 313/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.5000
# Epoch 314/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.5000
# Epoch 315/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9917 - val_accuracy: 0.5000
# Epoch 316/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9916 - val_accuracy: 0.5000
# Epoch 317/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9915 - val_accuracy: 0.5000
# Epoch 318/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9914 - val_accuracy: 0.5000
# Epoch 319/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9913 - val_accuracy: 0.5000
# Epoch 320/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9912 - val_accuracy: 0.5000
# Epoch 321/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9911 - val_accuracy: 0.5000
# Epoch 322/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9911 - val_accuracy: 0.5000
# Epoch 323/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9910 - val_accuracy: 0.5000
# Epoch 324/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9909 - val_accuracy: 0.5000
# Epoch 325/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.5000
# Epoch 326/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9907 - val_accuracy: 0.5000
# Epoch 327/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9906 - val_accuracy: 0.5000
# Epoch 328/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9905 - val_accuracy: 0.5000
# Epoch 329/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9904 - val_accuracy: 0.5000
# Epoch 330/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9903 - val_accuracy: 0.5000
# Epoch 331/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9902 - val_accuracy: 0.5000
# Epoch 332/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9901 - val_accuracy: 0.5000
# Epoch 333/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9900 - val_accuracy: 0.5000
# Epoch 334/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9900 - val_accuracy: 0.5000
# Epoch 335/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9899 - val_accuracy: 0.5000
# Epoch 336/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.9898 - val_accuracy: 0.5000
# Epoch 337/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.9897 - val_accuracy: 0.5000
# Epoch 338/500
# ...
# Epoch 389/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.9860 - val_accuracy: 0.5000
# Epoch 390/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.9859 - val_accuracy: 0.5000
# Epoch 391/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9859 - val_accuracy: 0.5000
# Epoch 392/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9858 - val_accuracy: 0.5000
# Epoch 393/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9857 - val_accuracy: 0.5000
# Epoch 394/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9857 - val_accuracy: 0.5000
# Epoch 395/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9856 - val_accuracy: 0.5000
# Epoch 396/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9856 - val_accuracy: 0.5000
# Epoch 397/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9855 - val_accuracy: 0.5000
# Epoch 398/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9855 - val_accuracy: 0.5000
# Epoch 399/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9854 - val_accuracy: 0.5000
# Epoch 400/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9853 - val_accuracy: 0.5000
# Epoch 401/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9853 - val_accuracy: 0.5000
# Epoch 402/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9852 - val_accuracy: 0.5000
# Epoch 403/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9852 - val_accuracy: 0.5000
# Epoch 404/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9851 - val_accuracy: 0.5000
# Epoch 405/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9851 - val_accuracy: 0.5000
# Epoch 406/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9850 - val_accuracy: 0.5000
# Epoch 407/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9850 - val_accuracy: 0.5000
# Epoch 408/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9849 - val_accuracy: 0.5000
# Epoch 409/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9849 - val_accuracy: 0.5000
# Epoch 410/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9848 - val_accuracy: 0.5000
# Epoch 411/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9848 - val_accuracy: 0.5000
# Epoch 412/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9847 - val_accuracy: 0.5000
# Epoch 413/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9847 - val_accuracy: 0.5000
# Epoch 414/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9846 - val_accuracy: 0.5000
# Epoch 415/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9846 - val_accuracy: 0.5000
# Epoch 416/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9845 - val_accuracy: 0.5000
# Epoch 417/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9845 - val_accuracy: 0.5000
# Epoch 418/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.5000
# Epoch 419/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.5000
# Epoch 420/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9843 - val_accuracy: 0.5000
# Epoch 421/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9843 - val_accuracy: 0.5000
# Epoch 422/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9842 - val_accuracy: 0.5000
# Epoch 423/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9842 - val_accuracy: 0.5000
# Epoch 424/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9842 - val_accuracy: 0.5000
# Epoch 425/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9841 - val_accuracy: 0.5000
# Epoch 426/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9841 - val_accuracy: 0.5000
# Epoch 427/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9840 - val_accuracy: 0.5000
# Epoch 428/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9840 - val_accuracy: 0.5000
# Epoch 429/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9839 - val_accuracy: 0.5000
# Epoch 430/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9839 - val_accuracy: 0.5000
# Epoch 431/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9838 - val_accuracy: 0.5000
# Epoch 432/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9838 - val_accuracy: 0.5000
# Epoch 433/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9838 - val_accuracy: 0.5000
# Epoch 434/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9837 - val_accuracy: 0.5000
# Epoch 435/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9837 - val_accuracy: 0.5000
# Epoch 436/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.5000
# Epoch 437/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.5000
# Epoch 438/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.5000
# Epoch 439/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9835 - val_accuracy: 0.5000
# Epoch 440/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9835 - val_accuracy: 0.5000
# Epoch 441/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9834 - val_accuracy: 0.5000
# Epoch 442/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9834 - val_accuracy: 0.5000
# Epoch 443/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9834 - val_accuracy: 0.5000
# Epoch 444/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9833 - val_accuracy: 0.5000
# Epoch 445/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9833 - val_accuracy: 0.5000
# Epoch 446/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9832 - val_accuracy: 0.5000
# Epoch 447/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9832 - val_accuracy: 0.5000
# Epoch 448/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9832 - val_accuracy: 0.5000
# Epoch 449/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9831 - val_accuracy: 0.5000
# Epoch 450/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9831 - val_accuracy: 0.5000
# Epoch 451/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9831 - val_accuracy: 0.5000
# Epoch 452/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.5000
# Epoch 453/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.5000
# Epoch 454/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.5000
# Epoch 455/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9829 - val_accuracy: 0.5000
# Epoch 456/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9829 - val_accuracy: 0.5000
# Epoch 457/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9828 - val_accuracy: 0.5000
# Epoch 458/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9828 - val_accuracy: 0.5000
# Epoch 459/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9828 - val_accuracy: 0.5000
# Epoch 460/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9827 - val_accuracy: 0.5000
# Epoch 461/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9827 - val_accuracy: 0.5000
# Epoch 462/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9827 - val_accuracy: 0.5000
# Epoch 463/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.5000
# Epoch 464/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.5000
# Epoch 465/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.5000
# Epoch 466/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9825 - val_accuracy: 0.5000
# Epoch 467/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9825 - val_accuracy: 0.5000
# Epoch 468/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9825 - val_accuracy: 0.5000
# Epoch 469/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9825 - val_accuracy: 0.5000
# Epoch 470/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9824 - val_accuracy: 0.5000
# Epoch 471/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9824 - val_accuracy: 0.5000
# Epoch 472/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9824 - val_accuracy: 0.5000
# Epoch 473/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9823 - val_accuracy: 0.5000
# Epoch 474/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9823 - val_accuracy: 0.5000
# Epoch 475/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9823 - val_accuracy: 0.5000
# Epoch 476/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.5000
# Epoch 477/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.5000
# Epoch 478/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.5000
# Epoch 479/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.5000
# Epoch 480/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.5000
# Epoch 481/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.5000
# Epoch 482/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.5000
# Epoch 483/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.5000
# Epoch 484/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.5000
# Epoch 485/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.5000
# Epoch 486/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.5000
# Epoch 487/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9819 - val_accuracy: 0.5000
# Epoch 488/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9819 - val_accuracy: 0.5000
# Epoch 489/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9819 - val_accuracy: 0.5000
# Epoch 490/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9818 - val_accuracy: 0.5000
# Epoch 491/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9818 - val_accuracy: 0.5000
# Epoch 492/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9818 - val_accuracy: 0.5000
# Epoch 493/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9818 - val_accuracy: 0.5000
# Epoch 494/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9817 - val_accuracy: 0.5000
# Epoch 495/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9817 - val_accuracy: 0.5000
# Epoch 496/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9817 - val_accuracy: 0.5000
# Epoch 497/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9817 - val_accuracy: 0.5000
# Epoch 498/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9816 - val_accuracy: 0.5000
# Epoch 499/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9816 - val_accuracy: 0.5000
# Epoch 500/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9816 - val_accuracy: 0.5000
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
mostrar_detalle_imagenes_entrenamiento = False #@param {type:"boolean"}

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map, mostrarImagenes=False):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if mostrarImagenes:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    if mostrarImagenes:
      print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map, mostrar_detalle_imagenes_entrenamiento)
# Out:
# *** Resultados con datos de Entrenamiento:
# 1/1 [==============================] - 0s 57ms/step
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#      2 dedos       1.00      1.00      1.00         5
#      3 dedos       1.00      0.80      0.89         5
#      4 dedos       0.83      1.00      0.91         5
#      5 dedos       1.00      1.00      1.00         5
#
#     accuracy                           0.95        20
#    macro avg       0.96      0.95      0.95        20
# weighted avg       0.96      0.95      0.95        20
#
#
# Matriz de Confusión:
#            p:3 dedos  p:5 dedos  p:4 dedos  p:2 dedos
# r:3 dedos          4          0          1          0
# r:5 dedos          0          5          0          0
# r:4 dedos          0          0          5          0
# r:2 dedos          0          0          0          5

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
mostrar_detalle_imagenes_prueba = False #@param {type:"boolean"}
 
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map, mostrar_detalle_imagenes_prueba)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9157 - accuracy: 0.6596
#
# >Evaluación del Modelo:
#     - Error:  0.9157357811927795
#     - Exactitud:  65.95744490623474
#
#
#
#
# *** Resultados con datos de Prueba:
# 2/2 [==============================] - 0s 5ms/step
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#      2 dedos       0.86      0.60      0.71        10
#      3 dedos       0.72      0.81      0.76        16
#      4 dedos       0.43      0.50      0.46         6
#      5 dedos       0.60      0.60      0.60        15
#
#     accuracy                           0.66        47
#    macro avg       0.65      0.63      0.63        47
# weighted avg       0.67      0.66      0.66        47
#
#
# Matriz de Confusión:
#            p:3 dedos  p:5 dedos  p:4 dedos  p:2 dedos
# r:3 dedos         13          3          0          0
# r:5 dedos          3          9          2          1
# r:4 dedos          2          1          3          0
# r:2 dedos          0          2          2          6
